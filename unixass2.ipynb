# %% [markdown]
# <a href="https://colab.research.google.com/github/Hannah1123/Pytorch_note/blob/main/unixass2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import re
import os


if os.access(sys.argv[2], os.R_OK):
    fin = open(sys.argv[2], 'r')
else:
    print('Error: file reading not possible')

#if sys.argv[1] = '-a':



fin = open(sys.argv[2])

f2list  = []
for line in fin:
    line = line.rstrip('\n')
    fields = re.split(',', line)    
    if fields[2] not in f2list:
        f2list.append(fields[2])

if f2list == []:
    print('No printing users')
else:
    print('Printing users:')
    for item in f2list:
        print(item)
    


#if sys.argv[1] = '-f'

line_num = 0
fin = open(sys.argv[2])
for line in fin:
 
    line_num += 1

print('Total number of files printed:', line_num)



#if sys.argv[1] = '-s'

fin = open(sys.argv[2])
num_bi = 0
for line in fin:
    line = line.rstrip('\n')
    fields = re.split(',', line)    
    num_bi += int(fields[1])

print('Total number of bytes printed:', num_bi)



#if sys.argv[1] = '-u' sys.argv[2] = username
username = sys.argv[2]
tot_num  = 0
tot_file = 0
num_list = []
for line in fin:
    line = line.rstrip('\n')
    fields = re.split(',', line) 
    if username == fields[2]:
        num_list.append(int(fields[1]))
        tot_num += int(fields[1])
        tot_file += 1
if num_list == []:
    print('User %s not found' % username)
else:
    larg_file = max(num_list)
    print('User', sys.argv[2])
    print('Total number of files printed:', tot_file)
    print('Total number of bytes printed:', tot_num)
    print('Largest file printed:', larg_file)

# %%
#!/usr/bin/env python3
import sys
import re
import os


def ops_a():
    fin = open(sys.argv[2])
    f2list  = []
    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)    
        if fields[2] not in f2list:
              f2list.append(fields[2])
    if f2list == []:
        print('No printing users')
    else:
        print('Printing users:')
        for item in f2list:
            print(item)


def ops_f():
    line_num = 0
    fin = open(sys.argv[2])
    for line in fin:
 
        line_num += 1

    print('Total number of files printed:', line_num)



def ops_s():
    fin = open(sys.argv[2])
    num_bi = 0
    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)    
        num_bi += int(fields[1])

    print('Total number of bytes printed:', num_bi)


def ops_u():
    tot_num  = 0
    tot_file = 0
    num_list = []

    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)
        username = sys.argv[2]

        if username == fields[2]:
            num_list.append(int(fields[1]))
            tot_num += int(fields[1])
            tot_file += 1
#print(num_list)
    if num_list == []:
        print('User %s not found' % username)
    else:
        larg_file = max(num_list)
        print('User', sys.argv[2])
        print('Total number of files printed:', tot_file)
        print('Total number of bytes printed:', tot_num)
        print('Largest file printed:', larg_file)

def ops_v():
    print('Wanrong Hong')
    print('13135684')
    print('01/06/2020')
    print("Happy Children's Day!!!")

# %%
#!/usr/bin/env python3
import sys
import re
import os


def ops_a(file_name):
    fin = open(file_name)
    f2list  = []
    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)    
        if fields[2] not in f2list:
              f2list.append(fields[2])
    if f2list == []:
        print('No printing users')
    else:
        print('Printing users:')
        for item in f2list:
            print(item)


def ops_f(file_name):
    line_num = 0
    fin = open(file_name)
    for line in fin:
 
        line_num += 1

    print('Total number of files printed:', line_num)



def ops_s(file_name):
    fin = open(file_name)
    num_bi = 0
    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)    
        num_bi += int(fields[1])

    print('Total number of bytes printed:', num_bi)


def ops_u(username, file_name):
    tot_num  = 0
    tot_file = 0
    num_list = []
    fin = open(file_name)

    for line in fin:
        line = line.rstrip('\n')
        fields = re.split(',', line)
        #username = sys.argv[2]

        if username == fields[2]:
            num_list.append(int(fields[1]))
            tot_num += int(fields[1])
            tot_file += 1

    if num_list == []:
        print('User %s not found' % username)
    else:
        larg_file = max(num_list)
        print('User', username)
        print('Total number of files printed:', tot_file)
        print('Total number of bytes printed:', tot_num)
        print('Largest file printed:', larg_file)

def ops_v(file_name):
    print('Wanrong Hong')
    print('13135684')
    print('01/06/2020')
    print("Happy Children's Day!!!")

# %%
#!/usr/bin/env python3
import sys
import re
import os
import utils as u

if len(sys.argv) == 3:
    if os.access(sys.argv[2], os.R_OK):
        fin = open(sys.argv[2], 'r')
    else:
        print('Error: file reading not possible')

    option = sys.argv[1]
    file_name = sys.argv[2]

    if sys.argv[1] == '-a':
        u.ops_a(file_name)

    elif sys.argv[1] == '-f':
        u.ops_f(file_name)

    elif sys.argv[1] == '-s':
        u.ops_s(file_name)

    elif sys.argv[1] == '-v':
        u.ops_v(file_name)
    
    else:
        print('Error option')

elif len(sys.argv) == 4:
    
    if os.access(sys.argv[3], os.R_OK):
        fin = open(sys.argv[3], 'r')
    else:
        print('Error: file reading not possible')
    
    option = sys.argv[1]
    username = sys.argv[2]
    file_name = sys.argv[3]
    

    if option == '-u':
        u.ops_u(username,file_name)
    else:
        print('Error option')

elif len(sys.argv) == 2 and sys.argv[1] == '-v':
    u.ops_v(file_name)

else:
    print('Error option')
